# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ml_pipeline.train_utils import plot_actual_vs_predicted, plot_residuals_histogram

# %%
import numpy as np

# %%
x = np.linspace(0,10,100)

# %%
y = x + [np.random.normal(0.1) for i in range(len(x))]

# %%
fig = plot_actual_vs_predicted(x,y)

# %%
fig

# %%
plot_residuals_histogram(x,y)
